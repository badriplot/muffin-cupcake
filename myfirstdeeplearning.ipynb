# %% [markdown]
# <a href="https://colab.research.google.com/github/badriplot/muffin-cupcake/blob/master/myfirstdeeplearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
observation = 1000
xs=np.random.uniform(low=-10,high=10,size=(observation,1))
zs=np.random.uniform(low=-10,high=10,size=(observation,1))

# %%
generated_inputs = np.column_stack((xs,zs))
noise = np.random.uniform(-1,1,(observation,1))

# %%
generated_targets = 2*xs-3*zs+5+noise

# %%
np.savez('TF_intro',inputs=generated_inputs,targets=generated_targets)

# %%
training_data=np.load('TF_intro.npz')

# %%
input_size = 2
output_size =1
model =tf.keras.Sequential([
                            tf.keras.layers.Dense(output_size)])



model.compile(optimizer='sgd',loss='mean_squared_error')


model.fit(training_data['inputs'],training_data['targets'],epochs=200,verbose=2)
# Out:
# Epoch 1/200
# 32/32 - 0s - loss: 31.6369
# Epoch 2/200
# 32/32 - 0s - loss: 4.4623
# Epoch 3/200
# 32/32 - 0s - loss: 1.4404
# Epoch 4/200
# 32/32 - 0s - loss: 0.6353
# Epoch 5/200
# 32/32 - 0s - loss: 0.4283
# Epoch 6/200
# 32/32 - 0s - loss: 0.3737
# Epoch 7/200
# 32/32 - 0s - loss: 0.3569
# Epoch 8/200
# 32/32 - 0s - loss: 0.3496
# Epoch 9/200
# 32/32 - 0s - loss: 0.3552
# Epoch 10/200
# 32/32 - 0s - loss: 0.3520
# Epoch 11/200
# 32/32 - 0s - loss: 0.3464
# Epoch 12/200
# 32/32 - 0s - loss: 0.3571
# Epoch 13/200
# 32/32 - 0s - loss: 0.3437
# Epoch 14/200
# 32/32 - 0s - loss: 0.3500
# Epoch 15/200
# 32/32 - 0s - loss: 0.3624
# Epoch 16/200
# 32/32 - 0s - loss: 0.3476
# Epoch 17/200
# 32/32 - 0s - loss: 0.3516
# Epoch 18/200
# 32/32 - 0s - loss: 0.3523
# Epoch 19/200
# 32/32 - 0s - loss: 0.3488
# Epoch 20/200
# 32/32 - 0s - loss: 0.3480
# Epoch 21/200
# 32/32 - 0s - loss: 0.3530
# Epoch 22/200
# 32/32 - 0s - loss: 0.3500
# Epoch 23/200
# 32/32 - 0s - loss: 0.3494
# Epoch 24/200
# ...

# %%
model.layers[0].get_weights()
# Out:
# [array([[ 2.0469828],
#         [-2.9360988]], dtype=float32), array([4.993319], dtype=float32)]

# %%
weights=model.layers[0].get_weights()[0]
weights
# Out:
# array([[ 2.0469828],
#        [-2.9360988]], dtype=float32)

# %%
bais=model.layers[0].get_weights()[1]
bais
# Out:
# array([4.993319], dtype=float32)

# %%
model.predict_on_batch(training_data['inputs']).round(1)
# Out:
# array([[  4.8],
#        [ -9. ],
#        [ 28.3],
#        [-15.2],
#        [ 21.7],
#        [ 18.9],
#        [-39.8],
#        [ -2.5],
#        [ 22.5],
#        [-31.1],
#        [ -0.4],
#        [-12.9],
#        [ 21.6],
#        [ 18.9],
#        [-26.5],
#        [ -9.5],
#        [ 28. ],
#        [  6. ],
#        [ 10.3],
#        [ 44.8],
#        [-17.1],
#        [ 31.5],
#        [  7. ],
#        [  4.5],
#        [ 18.3],
#        [-13.3],
#        [-20.1],
#        [ 38.3],
#        [  3.3],
#        [-11.5],
#        [ 35.8],
#        [ 10.6],
#        [-20.9],
#        [-11.8],
#        [ -0.6],
#        [ 25.8],
#        [ 22.1],
#        [ 17.2],
#        [-27.2],
#        [ 28.4],
#        [ 11.3],
#        [ 45.1],
#        [  6.5],
#        [ 17.6],
#        [  2.2],
#        [ 22.3],
#        [ 34. ],
#        [ 46.7],
#        [ 26.4],
#        [ 51.1],
#        [  4. ],
#        [-31.8],
#        [ 25.7],
#        [ -0.1],
#        [  6.6],
# ...

# %%
training_data['targets'].round(1)
# Out:
# array([[  3.5],
#        [ -8.2],
#        [ 29.5],
#        [-15.3],
#        [ 22.2],
#        [ 20.2],
#        [-40.9],
#        [ -3.2],
#        [ 22.8],
#        [-32.4],
#        [ -1. ],
#        [-12. ],
#        [ 21. ],
#        [ 17.5],
#        [-26.1],
#        [ -9.7],
#        [ 27.4],
#        [  6.4],
#        [ 11.7],
#        [ 44.2],
#        [-16.4],
#        [ 31. ],
#        [  6.1],
#        [  3.9],
#        [ 19.2],
#        [-13.5],
#        [-19.3],
#        [ 37.9],
#        [  4.5],
#        [-11. ],
#        [ 35.8],
#        [ 10.5],
#        [-21.8],
#        [-11.8],
#        [ -0.3],
#        [ 25.3],
#        [ 21.9],
#        [ 17.5],
#        [-27. ],
#        [ 28.1],
#        [ 11.8],
#        [ 46. ],
#        [  6.4],
#        [ 18.5],
#        [  3.2],
#        [ 23. ],
#        [ 33.7],
#        [ 46.4],
#        [ 27.5],
#        [ 51.2],
#        [  3.7],
#        [-31.2],
#        [ 25.5],
#        [ -0.5],
#        [  7. ],
# ...

# %%
plt.plot(np.squeeze(model.predict_on_batch(training_data['inputs'])),np.squeeze(training_data['targets']))
plt.xlabel('outputs')
plt.ylabel('targets')
plt.show()
